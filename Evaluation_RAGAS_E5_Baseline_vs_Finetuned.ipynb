# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["OMP_NUM_THREADS"] = "1"

# %%
import pandas as pd
import json
import os
import faiss
import logging
import numpy as np 
import torch
import gc
from dataclasses import dataclass, field
from typing import Dict, List, Optional, Callable, Tuple

from datasets import Dataset
from sentence_transformers import SentenceTransformer
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from ragas import evaluate
from ragas.metrics import context_precision, context_recall
from langchain_ollama import ChatOllama, OllamaEmbeddings
from ragas.run_config import RunConfig

# Logger configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%H:%M:%S', force=True)
logger = logging.getLogger("RAGEval_20_20")

os.environ["TOKENIZERS_PARALLELISM"] = "false"

@dataclass
class EvalConfig:
    # Chemins des données
    path_ir_dataset: str = "bercy_test_10.jsonl"
    path_ragas_dataset: str = "bercy_golden_dataset.jsonl"
    output_dir: str = "./results_final_20_20"
    
    # Juge LLM (Ollama)
    llm_judge: str = "llama3"
    embedding_judge: str = "nomic-embed-text"
    ollama_url: str = "http://localhost:11434"
    
    # Paramètres d'Exécution
    batch_size: int = 1      
    top_k: int = 5
    
    # Instruction par défaut (Référence centrale)
    default_instruction: str = "Retrieve the definition of an administrative acronym or term."

config = EvalConfig()
os.makedirs(config.output_dir, exist_ok=True)
print("Configuration chargée.")
# Out:
# ✅ Cellule 1 : Configuration chargée.
# /var/folders/kq/9_tnghtd41b632l1kx_xszk80000gn/T/ipykernel_2829/2427464594.py:16: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall
# /var/folders/kq/9_tnghtd41b632l1kx_xszk80000gn/T/ipykernel_2829/2427464594.py:16: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall

# %%
class RAGEvaluator:
    def __init__(self, config: EvalConfig):
        self.cfg = config
        self.judge_llm = ChatOllama(model=self.cfg.llm_judge, temperature=0, base_url=self.cfg.ollama_url)
        self.eval_embeddings = OllamaEmbeddings(model=self.cfg.embedding_judge, base_url=self.cfg.ollama_url)
        self.ragas_run_config = RunConfig(max_workers=1, timeout=360)
        self.ragas_data = self._load_ragas_data()
        
    def _load_ragas_data(self):
        logger.info(f"Chargement des données Ragas...")
        try:
            df = pd.read_json(self.cfg.path_ragas_dataset, lines=True)
            # Déduplication du corpus
            corpus = list(set([c[0] if isinstance(c, list) else c for c in df['ground_truth']]))
            return {"df": df, "corpus": corpus}
        except Exception as e:
            logger.critical(f"Erreur lecture dataset Ragas: {e}")
            raise e

    def sanity_check(self, model_path: str, local_only: bool) -> bool:
        logger.info("Sanity Check...")
        try:
            # Test Modèle
            model = SentenceTransformer(model_path, device="cpu", local_files_only=local_only)
            model.encode(["test"], convert_to_numpy=True)
            # Test Ollama
            ds = Dataset.from_dict({'question': ["t"], 'ground_truth': ["t"], 'contexts': [["t"]]})
            evaluate(ds, metrics=[context_precision], llm=self.judge_llm, embeddings=self.eval_embeddings, raise_exceptions=True)
            logger.info("Système Sain.")
            return True
        except Exception as e:
            logger.critical(f" ÉCHEC SANITY CHECK : {e}")
            return False

    def get_formatting_functions(self, model_alias: str, instruction: Optional[str] = None) -> Tuple[Callable, Callable, bool]:
        alias = model_alias.lower()
        
        if instruction or "config" in alias or "ft" in alias or "instruct" in alias:
            task_desc = instruction if instruction else self.cfg.default_instruction
            prompt = f"Instruct: {task_desc}\nQuery: "
            logger.info(f"Mode INSTRUCT appliqué.\n  Prompt: '{prompt.strip()}...'")
            return (lambda q: f"{prompt}{q}"), (lambda d: d), True
        
        elif "e5" in alias and "base" in alias:
            logger.info("Mode E5 STANDARD (query:/passage:) appliqué.")
            return (lambda q: f"query: {q}"), (lambda d: f"passage: {d}"), True
        
        else:
            logger.warning("Mode BRUT (Pas de préfixe).")
            return (lambda q: q), (lambda d: d), False

    def evaluate_model(self, model_config: Dict):
        
        path = model_config["path"]
        alias = model_config["alias"]
        local_only = model_config["local_only"]
        custom_instruct = model_config.get("instruction", None)
        logger.info(f"\n{'='*60}\n ÉVALUATION : {alias}\n{'='*60}")
        
        if not self.sanity_check(path, local_only):
            return {"Modèle": alias, "Error": "Sanity Check Failed"}

        #  Configuration du formatage
        prefix_q, prefix_d, do_norm = self.get_formatting_functions(alias, custom_instruct)

        try:
            model = SentenceTransformer(path, device="cpu", local_files_only=local_only)
        except Exception as e:
            logger.error(f"Erreur chargement modèle local: {e}")
            logger.info("Tentative de chargement sans restriction locale...")
            try:
                model = SentenceTransformer(path, device="cpu")
            except Exception as e2:
                return {"Modèle": alias, "Error": f"Load Error: {e2}"}

        metrics = {"Modèle": alias}

        # Information Retrieval (MRR/NDCG)
        logger.info("Phase IR (Retrieval metrics)...")
        try:
            # Chargement et préparation dataset 
            with open(self.cfg.path_ir_dataset, 'r', encoding='utf-8') as f:
                ir_data = [json.loads(line) for line in f]
            
            queries, corpus, rel_docs = {}, {}, {}
            for idx, row in enumerate(ir_data):
                qid, docid = str(idx), f"doc_{idx}"
                queries[qid] = prefix_q(row['anchor'])
                corpus[docid] = prefix_d(row['positive'])
                rel_docs[qid] = {docid}
            
            ir_eval = InformationRetrievalEvaluator(
                queries, corpus, rel_docs, name=alias[:10], 
                show_progress_bar=False, mrr_at_k=[10], ndcg_at_k=[10]
            )
            ir_res = ir_eval(model)
            
            # Récupération dynamique des clés
            metrics['MRR@10'] = next((v for k, v in ir_res.items() if 'mrr@10' in k.lower()), 0)
            metrics['NDCG@10'] = next((v for k, v in ir_res.items() if 'ndcg@10' in k.lower()), 0)
            logger.info(f"IR Score: MRR@10 = {metrics['MRR@10']:.4f}")

        except Exception as e:
            logger.error(f" Erreur Phase IR: {e}")
            metrics['MRR@10'] = 0.0

        # RAGAS (Precision/Recall) 
        logger.info(" Phase RAGAS (LLM Judge)...")
        
        # Encodage Corpus
        logger.info("Indexation du corpus...")
        corpus_txt = [prefix_d(d) for d in self.ragas_data['corpus']]
        corpus_emb = model.encode(
            corpus_txt, normalize_embeddings=do_norm, 
            batch_size=8, show_progress_bar=True, convert_to_numpy=True
        )
        index = faiss.IndexFlatIP(corpus_emb.shape[1])
        index.add(corpus_emb)
        
        # Batch processing
        questions = self.ragas_data['df']['question'].tolist()
        ground_truths = self.ragas_data['df']['ground_truth'].tolist()
        ragas_batches = []
        
        for i in range(0, len(questions), self.cfg.batch_size):
            gc.collect() 
            
            batch_q = questions[i : i + self.cfg.batch_size]
            batch_gt = ground_truths[i : i + self.cfg.batch_size]
            
            try:
                # Retrieval
                q_fmt = [prefix_q(q) for q in batch_q]
                q_emb = model.encode(q_fmt, normalize_embeddings=do_norm, convert_to_numpy=True)
                _, indices = index.search(q_emb, self.cfg.top_k)
                batch_ctx = [[self.ragas_data['corpus'][idx] for idx in row] for row in indices]
                
                # Eval
                ds = Dataset.from_dict({'question': batch_q, 'ground_truth': batch_gt, 'contexts': batch_ctx})
                res = evaluate(ds, metrics=[context_precision, context_recall], llm=self.judge_llm, embeddings=self.eval_embeddings, raise_exceptions=False)
                ragas_batches.append(res.to_pandas())
                
                if (i // self.cfg.batch_size) % 5 == 0:
                    logger.info(f"Progress: {i}/{len(questions)} queries")
                    
            except Exception as e:
                logger.error(f"Erreur Batch {i}: {e}")
                continue

        if ragas_batches:
            full_df = pd.concat(ragas_batches)
            metrics['Context Precision'] = full_df['context_precision'].mean()
            metrics['Context Recall'] = full_df['context_recall'].mean()
        else:
            metrics['Context Precision'] = 0.0
            metrics['Context Recall'] = 0.0
            
        logger.info(f"RÉSULTATS : {metrics}")
        
        # Nettoyage
        del model, index, corpus_emb
        gc.collect()
        if torch.backends.mps.is_available():
            torch.mps.empty_cache()
            
        return metrics

# Instanciation globale
evaluator = RAGEvaluator(config)
print("Moteur d'évaluation chargé (Correction NameError appliquée).")
# Out:
# 02:13:18 - INFO - 📂 Chargement des données Ragas...
# ✅ Cellule 2 : Moteur d'évaluation chargé (Correction NameError appliquée).

# %%
INSTRUCTION_BERCY = "Retrieve the definition of an administrative acronym or term."

models_campaign = [
    
    # 2. Config 1
    {
        "alias": "E5-FT-Config1",
        "path": "./e5_large_finetuned_config1_merged",
        "local_only": True,
        "instruction": INSTRUCTION_BERCY
    },
    # 3. Config 2
    {
        "alias": "E5-FT-Config2",
        "path": "./e5_large_finetuned_config2_merged_v2",
        "local_only": True,
        "instruction": INSTRUCTION_BERCY
    },
    # 4. Config 3
    {
        "alias": "E5-FT-Config3",
        "path": "./e5_large_finetuned_config3_merged",
        "local_only": True,
        "instruction": INSTRUCTION_BERCY
    },
    # 5. Config 4
    {
        "alias": "E5-FT-Config4",
        "path": "./e5_large_finetuned_config4_merged_v2",
        "local_only": True,
        "instruction": INSTRUCTION_BERCY
    },
e5_large_finetuned_config4_merged_v2
    # 1. Modèle de Base (Référence)
    {
        "alias": "E5-Base-Instruct",
        "path": "intfloat/multilingual-e5-large-instruct",
        "local_only": False,
        "instruction": None 
    }
]
print(f"Campagne configurée avec {len(models_campaign)} modèles.")
# Out:
# ✅ Cellule 3 : Campagne configurée avec 5 modèles.

# %%
all_results = []

print(f"Lancement sur {len(models_campaign)} modèles...\n")

for model_cfg in models_campaign:
    if model_cfg["local_only"] and not os.path.exists(model_cfg["path"]):
        print(f"Dossier introuvable pour {model_cfg['alias']} ({model_cfg['path']}). On passe.")
        continue
    res = evaluator.evaluate_model(model_cfg)
    all_results.append(res)
    pd.DataFrame(all_results).to_csv("resultats_progressifs_20_20.csv", index=False)

print("\n Calculs terminés.")
# Out:
# 12:52:19 - INFO -
# ============================================================
# 🚀 ÉVALUATION : E5-FT-Config1
# ============================================================
# 12:52:19 - INFO - 🩺 Sanity Check...
# 12:52:19 - INFO - Load pretrained SentenceTransformer: ./e5_large_finetuned_config1_merged
# 12:52:19 - WARNING - You are trying to use a model that was created with Sentence Transformers version 5.2.0, but you're currently using version 5.1.2. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# 🚀 Lancement de la campagne sur 5 modèles...
# The tokenizer you are loading from './e5_large_finetuned_config1_merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Batches: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]12:52:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 1/1 [00:04<00:00,  4.56s/it]
# 12:52:26 - INFO - ✅ Système Sain.
# 12:52:26 - INFO -    ⚙️  Mode INSTRUCT appliqué.
#        👉 Prompt: 'Instruct: Retrieve the definition of an administrative acronym or term.
# Query:...'
# 12:52:26 - INFO - Load pretrained SentenceTransformer: ./e5_large_finetuned_config1_merged
# 12:52:26 - WARNING - You are trying to use a model that was created with Sentence Transformers version 5.2.0, but you're currently using version 5.1.2. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# The tokenizer you are loading from './e5_large_finetuned_config1_merged' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# 12:52:27 - INFO - 1️⃣  Phase IR (Retrieval metrics)...
# 12:52:27 - INFO - Information Retrieval Evaluation of the model on the E5-FT-Conf dataset:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 13
#      10     continue
#      12 # Lancement de l'évaluation
# ---> 13 res = evaluator.evaluate_model(model_cfg)
#      14 all_results.append(res)
#      16 # Sauvegarde intermédiaire (Sécurité anti-crash)
#      17 # Si ça plante, tu auras au moins les résultats des modèles précédents
#
# Cell In[8], line 115, in RAGEvaluator.evaluate_model(self, model_config)
#     109     rel_docs[qid] = {docid}
#     111 ir_eval = InformationRetrievalEvaluator(
#     112     queries, corpus, rel_docs, name=alias[:10],
#     113     show_progress_bar=False, mrr_at_k=[10], ndcg_at_k=[10]
#     114 )
# --> 115 ir_res = ir_eval(model)
#     117 # Récupération dynamique des clés
#     118 metrics['MRR@10'] = next((v for k, v in ir_res.items() if 'mrr@10' in k.lower()), 0)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:237, in InformationRetrievalEvaluator.__call__(self, model, output_path, epoch, steps, *args, **kwargs)
#     234     self.score_function_names = [model.similarity_fn_name]
#     235     self._append_csv_headers(self.score_function_names)
# --> 237 scores = self.compute_metrices(model, output_path=output_path, *args, **kwargs)
#     239 # Write results to disk
#     240 if output_path is not None and self.write_csv:
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:332, in InformationRetrievalEvaluator.compute_metrices(self, model, corpus_model, corpus_embeddings, output_path)
#     330 # Encode chunk of corpus
#     331 if corpus_embeddings is None:
# --> 332     sub_corpus_embeddings = self.embed_inputs(
#     333         corpus_model,
#     334         self.corpus[corpus_start_idx:corpus_end_idx],
#     335         encode_fn_name="document",
#     336         prompt_name=self.corpus_prompt_name,
#     337         prompt=self.corpus_prompt,
#     338     )
#     339 else:
#     340     sub_corpus_embeddings = corpus_embeddings[corpus_start_idx:corpus_end_idx]
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/evaluation/InformationRetrievalEvaluator.py:426, in InformationRetrievalEvaluator.embed_inputs(self, model, sentences, encode_fn_name, prompt_name, prompt, **kwargs)
#     424 elif encode_fn_name == "document":
#     425     encode_fn = model.encode_document
# --> 426 return encode_fn(
#     427     sentences,
#     428     prompt_name=prompt_name,
#     429     prompt=prompt,
#     430     batch_size=self.batch_size,
#     431     show_progress_bar=self.show_progress_bar,
#     432     convert_to_tensor=True,
#     433     truncate_dim=self.truncate_dim,
#     434     **kwargs,
#     435 )
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:688, in SentenceTransformer.encode_document(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     685             prompt_name = candidate_prompt_name
#     686             break
# --> 688 return self.encode(
#     689     sentences=sentences,
#     690     prompt_name=prompt_name,
#     691     prompt=prompt,
#     692     batch_size=batch_size,
#     693     show_progress_bar=show_progress_bar,
#     694     output_value=output_value,
#     695     precision=precision,
#     696     convert_to_numpy=convert_to_numpy,
#     697     convert_to_tensor=convert_to_tensor,
#     698     device=device,
#     699     normalize_embeddings=normalize_embeddings,
#     700     truncate_dim=truncate_dim,
#     701     pool=pool,
#     702     chunk_size=chunk_size,
#     703     task="document",
#     704     **kwargs,
#     705 )
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/sentence_transformers/models/Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)
#     257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:853, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     846 # Prepare head mask if needed
#     847 # 1.0 in head_mask indicate we keep the head
#     848 # attention_probs has shape bsz x n_heads x N x N
#     849 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     850 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     851 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 853 encoder_outputs = self.encoder(
#     854     embedding_output,
#     855     attention_mask=extended_attention_mask,
#     856     head_mask=head_mask,
#     857     encoder_hidden_states=encoder_hidden_states,
#     858     encoder_attention_mask=encoder_extended_attention_mask,
#     859     past_key_values=past_key_values,
#     860     use_cache=use_cache,
#     861     output_attentions=output_attentions,
#     862     output_hidden_states=output_hidden_states,
#     863     return_dict=return_dict,
#     864     cache_position=cache_position,
#     865 )
#     866 sequence_output = encoder_outputs[0]
#     867 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:607, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     603     all_hidden_states = all_hidden_states + (hidden_states,)
#     605 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 607 layer_outputs = layer_module(
#     608     hidden_states,
#     609     attention_mask,
#     610     layer_head_mask,
#     611     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     612     encoder_attention_mask=encoder_attention_mask,
#     613     past_key_values=past_key_values,
#     614     output_attentions=output_attentions,
#     615     cache_position=cache_position,
#     616 )
#     618 hidden_states = layer_outputs[0]
#     619 if output_attentions:
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:544, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, output_attentions, cache_position)
#     541     attention_output = cross_attention_outputs[0]
#     542     outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
# --> 544 layer_output = apply_chunking_to_forward(
#     545     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     546 )
#     547 outputs = (layer_output,) + outputs
#     549 return outputs
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/pytorch_utils.py:257, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     254     # concatenate output at same dimension
#     255     return torch.cat(output_chunks, dim=chunk_dim)
# --> 257 return forward_fn(*input_tensors)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:553, in XLMRobertaLayer.feed_forward_chunk(self, attention_output)
#     551 def feed_forward_chunk(self, attention_output):
#     552     intermediate_output = self.intermediate(attention_output)
# --> 553     layer_output = self.output(intermediate_output, attention_output)
#     554     return layer_output
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:482, in XLMRobertaOutput.forward(self, hidden_states, input_tensor)
#     480 hidden_states = self.dense(hidden_states)
#     481 hidden_states = self.dropout(hidden_states)
# --> 482 hidden_states = self.LayerNorm(hidden_states + input_tensor)
#     483 return hidden_states
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/modules/normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File ~/Documents/PFE/PFE_RAGAS/venv/lib/python3.9/site-packages/torch/nn/functional.py:2905, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2895 if has_torch_function_variadic(input, weight, bias):
#    2896     return handle_torch_function(
#    2897         layer_norm,
#    2898         (input, weight, bias),
#    (...)
#    2903         eps=eps,
#    2904     )
# -> 2905 return torch.layer_norm(
#    2906     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2907 )
#
# KeyboardInterrupt:

# %%
#RAPPORT FINAL 

if all_results:
    df_final = pd.DataFrame(all_results)
    
    # Réorganisation des colonnes pour la lisibilité
    desired_order = ['Modèle', 'MRR@10', 'NDCG@10', 'Context Precision', 'Context Recall']
    cols = [c for c in desired_order if c in df_final.columns]
   
    cols += [c for c in df_final.columns if c not in desired_order]
    
    print("\nCLASSEMENT FINAL")
    display(df_final[cols])
    df_final.to_csv("resultats_finaux_grand_chelem.csv", index=False)
    print("Sauvegardé dans 'resultats_finaux_grand_chelem.csv'")
else:
    print("Aucun résultat n'a été généré.")
# Out:
# 🏆 CLASSEMENT FINAL 🏆
#              Modèle    MRR@10   NDCG@10  Context Precision  Context Recall
# 0     E5-FT-Config1  0.138189  0.169041           0.625874        0.903098
# 1     E5-FT-Config2  0.509758  0.564977           0.957778        0.987037
# 2     E5-FT-Config3  0.522828  0.579678           0.958599        0.980835
# 3  E5-Base-Instruct  0.513838  0.572278           0.955579        0.971663
# Sauvegardé dans 'resultats_finaux_grand_chelem.csv'

# %%
missing_model = {
    "alias": "E5-FT-Config4-v2",
    "path": "./e5_large_finetuned_config4_merged_v2", 
    "local_only": True,
    "instruction": INSTRUCTION_BERCY
}

print(f"\nLancement du rattrapage pour : {missing_model['alias']}")

if os.path.exists(missing_model["path"]):
    res_missing = evaluator.evaluate_model(missing_model)
    all_results.append(res_missing)
    pd.DataFrame(all_results).to_csv("resultats_rattrapage.csv", index=False)
    print(f" {missing_model['alias']} ajouté avec succès !")
else:
    print(f" ERREUR : Le dossier '{missing_model['path']}' est introuvable.")
    print(" Vérifie le nom exact du dossier dans la barre de fichiers à gauche.")

# 3. Affichage du Tableau Complet Mis à Jour
print("\n CLASSEMENT FINAL (MIS À JOUR)")
if all_results:
    df_final = pd.DataFrame(all_results)
    
    # Mise en forme propre
    cols = ['Modèle', 'MRR@10', 'NDCG@10', 'Context Precision', 'Context Recall']
    cols = [c for c in cols if c in df_final.columns] 
    
    display(df_final[cols])
else:
    print("Aucun résultat en mémoire.")
# Out:
# 12:53:11 - INFO -
# ============================================================
# 🚀 ÉVALUATION : E5-FT-Config4-v2
# ============================================================
# 12:53:11 - INFO - 🩺 Sanity Check...
# 12:53:11 - INFO - Load pretrained SentenceTransformer: ./e5_large_finetuned_config4_merged_v2
# 12:53:11 - WARNING - You are trying to use a model that was created with Sentence Transformers version 5.2.0, but you're currently using version 5.1.2. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# 🚀 Lancement du rattrapage pour : E5-FT-Config4-v2
# The tokenizer you are loading from './e5_large_finetuned_config4_merged_v2' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Batches: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]12:53:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
# 12:53:16 - INFO - ✅ Système Sain.
# 12:53:16 - INFO -    ⚙️  Mode INSTRUCT appliqué.
#        👉 Prompt: 'Instruct: Retrieve the definition of an administrative acronym or term.
# Query:...'
# 12:53:16 - INFO - Load pretrained SentenceTransformer: ./e5_large_finetuned_config4_merged_v2
# 12:53:16 - WARNING - You are trying to use a model that was created with Sentence Transformers version 5.2.0, but you're currently using version 5.1.2. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# The tokenizer you are loading from './e5_large_finetuned_config4_merged_v2' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# 12:53:16 - INFO - 1️⃣  Phase IR (Retrieval metrics)...
# 12:53:16 - INFO - Information Retrieval Evaluation of the model on the E5-FT-Conf dataset:
# 12:53:34 - INFO - Queries: 468
# 12:53:34 - INFO - Corpus: 468
#
# 12:53:34 - INFO - Score-Function: cosine
# 12:53:34 - INFO - Accuracy@1: 35.68%
# 12:53:34 - INFO - Accuracy@3: 67.74%
# 12:53:34 - INFO - Accuracy@5: 69.87%
# 12:53:34 - INFO - Accuracy@10: 75.21%
# 12:53:34 - INFO - Precision@1: 35.68%
# 12:53:34 - INFO - Precision@3: 22.58%
# 12:53:34 - INFO - Precision@5: 13.97%
# 12:53:34 - INFO - Precision@10: 7.52%
# 12:53:34 - INFO - Recall@1: 35.68%
# 12:53:34 - INFO - Recall@3: 67.74%
# 12:53:34 - INFO - Recall@5: 69.87%
# 12:53:34 - INFO - Recall@10: 75.21%
# 12:53:34 - INFO - MRR@10: 0.5166
# 12:53:34 - INFO - NDCG@10: 0.5753
# 12:53:34 - INFO - MAP@100: 0.5247
# 12:53:34 - INFO -    📊 IR Score: MRR@10 = 0.5166
# 12:53:34 - INFO - 2️⃣  Phase RAGAS (LLM Judge)...
# 12:53:34 - INFO -    📚 Indexation du corpus...
# Batches: 100%|██████████| 44/44 [00:09<00:00,  4.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.91it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:53:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.41s/it]12:53:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:53:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:53:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:53:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.78s/it]
# 12:54:02 - INFO -    ✅ Progress: 0/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.83it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:54:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.06s/it]12:54:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.44s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.61it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:54:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.26s/it]12:54:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.35s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.48it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:54:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.09s/it]12:54:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:54:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.18s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.84it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:55:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.05s/it]12:55:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.03s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.39it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:55:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.95s/it]12:55:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.41s/it]
# 12:55:36 - INFO -    ✅ Progress: 5/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.48it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:55:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.73s/it]12:55:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:55:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.73s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.84it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:55:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:08<00:08,  8.50s/it]12:56:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:19<00:00,  9.66s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.45it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:56:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.07s/it]12:56:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.12s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.21it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:56:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.32s/it]12:56:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:56:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.27s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.35it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:56:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.07s/it]12:57:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:19<00:00,  9.54s/it]
# 12:57:13 - INFO -    ✅ Progress: 10/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.99it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:57:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.11s/it]12:57:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.61s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.06it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:57:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.17s/it]12:57:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:15<00:00,  7.76s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.86it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:57:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.97s/it]12:57:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:57:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.74s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.64it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:58:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.74s/it]12:58:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.79s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.78it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:58:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.20s/it]12:58:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.76s/it]
# 12:58:43 - INFO -    ✅ Progress: 15/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.93it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:58:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.46s/it]12:58:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:58:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.84s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:59:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.85s/it]12:59:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.04s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.83it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:59:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.76s/it]12:59:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.98s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.04it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]12:59:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.07s/it]12:59:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 12:59:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.13s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.60it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:00:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.75s/it]13:00:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.52s/it]
# 13:00:15 - INFO -    ✅ Progress: 20/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.16it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:00:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.51s/it]13:00:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.17s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.12it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:00:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.53s/it]13:00:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.88s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.67it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:00:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:00:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.88s/it]13:01:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.07s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.91it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:01:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.76s/it]13:01:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.48s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.47it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:01:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.73s/it]13:01:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.15s/it]
# 13:01:45 - INFO -    ✅ Progress: 25/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.03it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:01:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.25s/it]13:01:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:01:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.51s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.39it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:02:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.47s/it]13:02:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:15<00:00,  7.78s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.91it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:02:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.74s/it]13:02:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.06s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.06it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:02:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  7.00s/it]13:02:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:02:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.48s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.67it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:02:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.10s/it]13:03:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.41s/it]
# 13:03:14 - INFO -    ✅ Progress: 30/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.11it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:03:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.99s/it]13:03:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.83s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.31it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:03:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.85s/it]13:03:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.02s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.40it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:03:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:03:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.55s/it]13:04:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.09s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.44it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:04:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.54s/it]13:04:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:19<00:00,  9.74s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.42it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:04:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.08s/it]13:04:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.38s/it]
# 13:04:47 - INFO -    ✅ Progress: 35/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.87it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:04:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.63s/it]13:04:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:04:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.09s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:05:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.99s/it]13:05:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.88s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.54it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:05:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.60s/it]13:05:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.36s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.80it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:05:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.08s/it]13:05:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:05:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.98s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.20it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:06:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.86s/it]13:06:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.45s/it]
# 13:06:20 - INFO -    ✅ Progress: 40/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.70it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:06:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.42s/it]13:06:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.94s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.96it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:06:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.83s/it]13:06:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:06:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.75s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.24it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:06:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.42s/it]13:07:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.70s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:07:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.41s/it]13:07:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.43s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.04it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:07:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.99s/it]13:07:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:07:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.42s/it]
# 13:07:53 - INFO -    ✅ Progress: 45/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.97it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:07:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.03s/it]13:08:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.22s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.17it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:08:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:08<00:08,  8.03s/it]13:08:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.86s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:08:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.97s/it]13:08:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:08:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.75s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.70it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:08:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.94s/it]13:08:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:19<00:00,  9.70s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.87it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:09:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:08<00:08,  8.15s/it]13:09:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.84s/it]
# 13:09:28 - INFO -    ✅ Progress: 50/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.60it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:09:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.33s/it]13:09:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.34s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.10it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:09:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:09:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.72s/it]13:09:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.29s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.60it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:10:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.54s/it]13:10:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.49s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:10:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.45s/it]13:10:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.83s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.89it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:10:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.58s/it]13:10:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:10:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.35s/it]
# 13:11:06 - INFO -    ✅ Progress: 55/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.02it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:11:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.41s/it]13:11:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.26s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.19it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:11:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.52s/it]13:11:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.51s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.08it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:11:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.79s/it]13:11:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:11:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:12:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.12s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.35it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]13:12:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.90s/it]13:12:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:12:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:12:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 13:12:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ...
# 15:18:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:18:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:18:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:18:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.14s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.39it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:18:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:18:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.75s/it]15:19:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.66s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:19:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.78s/it]15:19:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:20<00:00, 10.33s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.30it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:19:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.92s/it]15:19:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.16s/it]
# 15:19:49 - INFO -    ✅ Progress: 450/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.37it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:19:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.38s/it]15:19:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:19:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.27s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.45it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:20:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:08<00:08,  8.02s/it]15:20:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.73s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.80it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:20:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.86s/it]15:20:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.03s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.87it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:20:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.92s/it]15:20:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:20:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.25s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.94it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:21:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.76s/it]15:21:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.05s/it]
# 15:21:22 - INFO -    ✅ Progress: 455/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.57it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:21:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.55s/it]15:21:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.60s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.91it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:21:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.24s/it]15:21:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:21:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.72s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:22:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.13s/it]15:22:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.50s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.35it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:22:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.95s/it]15:22:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.88s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.10it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:22:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.20s/it]15:22:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.05s/it]
# 15:22:54 - INFO -    ✅ Progress: 460/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:22:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:22:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.92s/it]15:23:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.50s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.63it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:23:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.63s/it]15:23:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:15<00:00,  7.80s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.13it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:23:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.99s/it]15:23:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:17<00:00,  8.73s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 18.05it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:23:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.56s/it]15:23:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:23:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:19<00:00,  9.58s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.05it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:24:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.64s/it]15:24:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.42s/it]
# 15:24:25 - INFO -    ✅ Progress: 465/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.87it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:24:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:08<00:08,  8.81s/it]15:24:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:18<00:00,  9.31s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.88it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]15:24:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:07<00:07,  7.66s/it]15:24:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:24:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 15:25:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:16<00:00,  8.35s/it]
# 15:25:02 - INFO - 🏆 RÉSULTATS : {'Modèle': 'E5-FT-Config4-v2', 'MRR@10': 0.5165920499253834, 'NDCG@10': 0.5752947971129673, 'Context Precision': np.float64(0.9578703703407684), 'Context Recall': np.float64(0.9878917378917379)}
# ✅ E5-FT-Config4-v2 ajouté avec succès !
#
# 🏆 CLASSEMENT FINAL (MIS À JOUR) 🏆
#              Modèle    MRR@10   NDCG@10  Context Precision  Context Recall
# 0  E5-FT-Config4-v2  0.516592  0.575295            0.95787        0.987892
