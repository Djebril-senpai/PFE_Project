# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["OMP_NUM_THREADS"] = "1"

# %%
import pandas as pd
import json
import os
import faiss
import logging
import numpy as np 
import torch
import gc
from dataclasses import dataclass, field
from typing import Dict, List, Optional, Callable, Tuple

from datasets import Dataset
from sentence_transformers import SentenceTransformer
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from ragas import evaluate
from ragas.metrics import context_precision, context_recall
from langchain_ollama import ChatOllama, OllamaEmbeddings
from ragas.run_config import RunConfig

# CONFIGURATION

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%H:%M:%S', force=True)
logger = logging.getLogger("RAGEval_20_20")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

@dataclass
class EvalConfig:
    # Chemins des données
    path_ir_dataset: str = "bercy_test_10.jsonl"
    path_ragas_dataset: str = "bercy_golden_dataset.jsonl"
    output_dir: str = "./results_final_20_20"
    
    # Juge LLM (Ollama)
    llm_judge: str = "llama3"
    embedding_judge: str = "nomic-embed-text"
    ollama_url: str = "http://localhost:11434"
    
    # Paramètres d'Exécution
    batch_size: int = 1      
    top_k: int = 5
    
    default_instruction: str = "Retrieve the definition of an administrative acronym or term."

config = EvalConfig()
os.makedirs(config.output_dir, exist_ok=True)
print("Cellule 1 : Configuration chargée.")
# Out:
# Cellule 1 : Configuration chargée.
# C:\Users\Djibs\AppData\Local\Temp\ipykernel_19884\3353891050.py:16: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall
# C:\Users\Djibs\AppData\Local\Temp\ipykernel_19884\3353891050.py:16: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall

# %% [markdown]
# ### **Retrieval & RAGAS**

# %%
class RAGEvaluator:
    def __init__(self, config: EvalConfig):
        self.cfg = config
        self.judge_llm = ChatOllama(model=self.cfg.llm_judge, temperature=0, base_url=self.cfg.ollama_url)
        self.eval_embeddings = OllamaEmbeddings(model=self.cfg.embedding_judge, base_url=self.cfg.ollama_url)
        self.ragas_run_config = RunConfig(max_workers=1, timeout=360)
        self.ragas_data = self._load_ragas_data()
        
    def _load_ragas_data(self):
        """Charge et prépare les données Ragas une seule fois."""
        logger.info(f"Chargement des données Ragas...")
        try:
            df = pd.read_json(self.cfg.path_ragas_dataset, lines=True)
            # Déduplication intelligente du corpus
            corpus = list(set([c[0] if isinstance(c, list) else c for c in df['ground_truth']]))
            return {"df": df, "corpus": corpus}
        except Exception as e:
            logger.critical(f"Erreur lecture dataset Ragas: {e}")
            raise e

    def sanity_check(self, model_path: str, local_only: bool) -> bool:
        """Vérifie la santé du modèle et du serveur Ollama avant de commencer."""
        logger.info("🩺 Sanity Check...")
        try:
            # Test Modèle
            model = SentenceTransformer(model_path, device="cpu", local_files_only=local_only)
            model.encode(["test"], convert_to_numpy=True)
            # Test Ollama
            ds = Dataset.from_dict({'question': ["t"], 'ground_truth': ["t"], 'contexts': [["t"]]})
            evaluate(ds, metrics=[context_precision], llm=self.judge_llm, embeddings=self.eval_embeddings, raise_exceptions=True)
            logger.info("Système Sain.")
            return True
        except Exception as e:
            logger.critical(f"ÉCHEC SANITY CHECK : {e}")
            return False

    def get_formatting_functions(self, model_alias: str, instruction: Optional[str] = None) -> Tuple[Callable, Callable, bool]:
        """
        Factory qui retourne les fonctions de formatage (Prefixes) adaptées au modèle.
        """
        alias = model_alias.lower()

        # CAS SOLON
        # Solon attend "query : " (avec espaces) pour les requêtes, et rien pour les passages.
        if "solon" in alias:
            logger.info("Mode SOLON (query : ) appliqué.")
            return (lambda q: f"query : {q}"), (lambda d: d), True

        logger.warning("Mode BRUT (Pas de préfixe).")
        return (lambda q: q), (lambda d: d), False

    def evaluate_model(self, model_config: Dict):
        """
        Exécute l'évaluation complète pour une configuration de modèle donnée.
        """
        # Extraction des variables depuis le dictionnaire
        path = model_config["path"]
        alias = model_config["alias"]
        local_only = model_config["local_only"]
        custom_instruct = model_config.get("instruction", None)

        logger.info(f"\n{'='*60}\nÉVALUATION : {alias}\n{'='*60}")
        
        if not self.sanity_check(path, local_only):
            return {"Modèle": alias, "Error": "Sanity Check Failed"}

        # 1. Configuration du formatage
        prefix_q, prefix_d, do_norm = self.get_formatting_functions(alias, custom_instruct)

        try:
            model = SentenceTransformer(path, device="cpu", local_files_only=local_only)
        except Exception as e:
            logger.error(f"Erreur chargement modèle local: {e}")
            logger.info("Tentative de chargement sans restriction locale...")
            try:
                # Tentative de secours si le path local échoue
                model = SentenceTransformer(path, device="cpu")
            except Exception as e2:
                return {"Modèle": alias, "Error": f"Load Error: {e2}"}

        metrics = {"Modèle": alias}

        # PHASE 1 : Information Retrieval (MRR/NDCG)
        logger.info("Phase IR (Retrieval metrics)...")
        try:
            # Chargement et préparation dataset IR à la volée
            with open(self.cfg.path_ir_dataset, 'r', encoding='utf-8') as f:
                ir_data = [json.loads(line) for line in f]
            
            queries, corpus, rel_docs = {}, {}, {}
            for idx, row in enumerate(ir_data):
                qid, docid = str(idx), f"doc_{idx}"
                queries[qid] = prefix_q(row['anchor'])
                corpus[docid] = prefix_d(row['positive'])
                rel_docs[qid] = {docid}
            
            ir_eval = InformationRetrievalEvaluator(
                queries, corpus, rel_docs, name=alias[:10], 
                show_progress_bar=False, mrr_at_k=[10], ndcg_at_k=[10]
            )
            ir_res = ir_eval(model)
            
            # Récupération dynamique des clés
            metrics['MRR@10'] = next((v for k, v in ir_res.items() if 'mrr@10' in k.lower()), 0)
            metrics['NDCG@10'] = next((v for k, v in ir_res.items() if 'ndcg@10' in k.lower()), 0)
            logger.info(f"IR Score: MRR@10 = {metrics['MRR@10']:.4f}")

        except Exception as e:
            logger.error(f"Erreur Phase IR: {e}")
            metrics['MRR@10'] = 0.0

        # PHASE 2 : RAGAS (Precision/Recall)
        logger.info("Phase RAGAS (LLM Judge)...")
        
        # Encodage Corpus
        logger.info("Indexation du corpus...")
        corpus_txt = [prefix_d(d) for d in self.ragas_data['corpus']]
        corpus_emb = model.encode(
            corpus_txt, normalize_embeddings=do_norm, 
            batch_size=8, show_progress_bar=True, convert_to_numpy=True
        )
        index = faiss.IndexFlatIP(corpus_emb.shape[1])
        index.add(corpus_emb)
        
        # Batch processing
        questions = self.ragas_data['df']['question'].tolist()
        ground_truths = self.ragas_data['df']['ground_truth'].tolist()
        ragas_batches = []
        
        for i in range(0, len(questions), self.cfg.batch_size):
            gc.collect()
            
            batch_q = questions[i : i + self.cfg.batch_size]
            batch_gt = ground_truths[i : i + self.cfg.batch_size]
            
            try:
                # Retrieval
                q_fmt = [prefix_q(q) for q in batch_q]
                q_emb = model.encode(q_fmt, normalize_embeddings=do_norm, convert_to_numpy=True)
                _, indices = index.search(q_emb, self.cfg.top_k)
                batch_ctx = [[self.ragas_data['corpus'][idx] for idx in row] for row in indices]
                
                # Eval
                ds = Dataset.from_dict({'question': batch_q, 'ground_truth': batch_gt, 'contexts': batch_ctx})
                res = evaluate(ds, metrics=[context_precision, context_recall], llm=self.judge_llm, embeddings=self.eval_embeddings, raise_exceptions=False)
                ragas_batches.append(res.to_pandas())
                
                if (i // self.cfg.batch_size) % 5 == 0:
                    logger.info(f"Progress: {i}/{len(questions)} queries")
                    
            except Exception as e:
                logger.error(f"Erreur Batch {i}: {e}")
                continue

        if ragas_batches:
            full_df = pd.concat(ragas_batches)
            metrics['Context Precision'] = full_df['context_precision'].mean()
            metrics['Context Recall'] = full_df['context_recall'].mean()
        else:
            metrics['Context Precision'] = 0.0
            metrics['Context Recall'] = 0.0
            
        logger.info(f"RÉSULTATS : {metrics}")
        
        # Nettoyage
        del model, index, corpus_emb
        gc.collect()
        if torch.backends.mps.is_available():
            torch.mps.empty_cache()
            
        return metrics

evaluator = RAGEvaluator(config)
print("Cellule 2 : Moteur d'évaluation chargé (Correction NameError appliquée).")
# Out:
# 19:03:52 - INFO - Chargement des données Ragas...
# Cellule 2 : Moteur d'évaluation chargé (Correction NameError appliquée).

# %% [markdown]
# ### **Liste des modèles Solon à tester (Baseline vs fine-tuner)**

# %%
INSTRUCTION_BERCY = "Retrieve the definition of an administrative acronym or term."

models_campaign = [

    # SOLON BASELINE

    {
        "alias": "Solon-Base-Large",
        "path": "OrdalieTech/SOLON-embeddings-large-0.1",
        "local_only": False,
        "instruction": None
    },

    # SOLON FT

    {
        "alias": "Solon-FT-Config1",
        "path": "./final_models/solon_large_finetuned_config1_merged",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config1-v2",
        "path": "./final_models/solon_large_finetuned_config1_merged_v2",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config2",
        "path": "./final_models/solon_large_finetuned_config2_merged",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config2-v2",
        "path": "./final_models/solon_large_finetuned_config2_merged_v2",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config3",
        "path": "./final_models/solon_large_finetuned_config3_merged",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config3-v2",
        "path": "./final_models/solon_large_finetuned_config3_merged_v2",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config4",
        "path": "./final_models/solon_large_finetuned_config4_merged",
        "local_only": True,
        "instruction": None
    },
    {
        "alias": "Solon-FT-Config4-v2",
        "path": "./final_models/solon_large_finetuned_config4_merged_v2",
        "local_only": True,
        "instruction": None
    },
]

print(f"Cellule 3 : Campagne configurée avec {len(models_campaign)} modèles.")
# Out:
#   Cell In[12], line 7
#     '''{
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### **Exécution des modèles**

# %%
all_results = []

print(f"Lancement de la campagne sur {len(models_campaign)} modèles...\n")

for model_cfg in models_campaign:
    # Vérification si le dossier existe
    if model_cfg["local_only"] and not os.path.exists(model_cfg["path"]):
        print(f"Dossier introuvable pour {model_cfg['alias']} ({model_cfg['path']}). On passe.")
        continue
        
    # Lancement de l'évaluation
    res = evaluator.evaluate_model(model_cfg)
    all_results.append(res)
    
    # Sauvegarde intermédiaire (Sécurité anti-crash)
    pd.DataFrame(all_results).to_csv("resultats_progressifs_20_20.csv", index=False)

print("\nCellule 4 : Calculs terminés.")
# Out:
# 19:05:21 - INFO -
# ============================================================
# ÉVALUATION : Solon-FT-Config4
# ============================================================
# 19:05:21 - INFO - 🩺 Sanity Check...
# 19:05:21 - INFO - Load pretrained SentenceTransformer: ./final_models/solon_large_finetuned_config4_merged
# Lancement de la campagne sur 2 modèles...
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 781.45it/s, Materializing param=pooler.dense.weight]
# Batches: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]19:05:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
# 19:05:31 - INFO - Système Sain.
# 19:05:31 - INFO - Mode SOLON (query : ) appliqué.
# 19:05:31 - INFO - Load pretrained SentenceTransformer: ./final_models/solon_large_finetuned_config4_merged
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 724.54it/s, Materializing param=pooler.dense.weight]
# 19:05:34 - INFO - Phase IR (Retrieval metrics)...
# 19:05:34 - INFO - Information Retrieval Evaluation of the model on the Solon-FT-C dataset:
# 19:09:28 - INFO - Queries: 468
# 19:09:28 - INFO - Corpus: 468
#
# 19:09:28 - INFO - Score-Function: cosine
# 19:09:28 - INFO - Accuracy@1: 36.32%
# 19:09:28 - INFO - Accuracy@3: 70.09%
# 19:09:28 - INFO - Accuracy@5: 72.65%
# 19:09:28 - INFO - Accuracy@10: 77.99%
# 19:09:28 - INFO - Precision@1: 36.32%
# 19:09:28 - INFO - Precision@3: 23.36%
# 19:09:28 - INFO - Precision@5: 14.53%
# 19:09:28 - INFO - Precision@10: 7.80%
# 19:09:28 - INFO - Recall@1: 36.32%
# 19:09:28 - INFO - Recall@3: 70.09%
# 19:09:28 - INFO - Recall@5: 72.65%
# 19:09:28 - INFO - Recall@10: 77.99%
# 19:09:28 - INFO - MRR@10: 0.5412
# 19:09:28 - INFO - NDCG@10: 0.6010
# 19:09:28 - INFO - MAP@100: 0.5481
# 19:09:28 - INFO - IR Score: MRR@10 = 0.5412
# 19:09:28 - INFO - Phase RAGAS (LLM Judge)...
# 19:09:28 - INFO - Indexation du corpus...
# Batches: 100%|██████████| 44/44 [02:15<00:00,  3.09s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:11:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:11:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:11:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.93s/it]19:11:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:11:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:11:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:14<00:00,  7.44s/it]
# 19:12:02 - INFO - Progress: 0/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:12:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.25s/it]19:12:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.93s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.78it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:12:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.36s/it]19:12:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.21s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:12:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.86s/it]19:12:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.74s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:12:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.09s/it]19:12:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:12:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.10s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.96it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:13:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.74s/it]19:13:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.71s/it]
# 19:13:13 - INFO - Progress: 5/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:13:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  4.00s/it]19:13:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.79s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:13:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.00s/it]19:13:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:13<00:00,  6.51s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:13:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.73s/it]19:13:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:13:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.75s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:13:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.52s/it]19:14:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.01s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:14:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.40s/it]19:14:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.18s/it]
# 19:14:25 - INFO - Progress: 10/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:14:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.88s/it]19:14:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.68s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:14:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.80s/it]19:14:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.67s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:14:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:14:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.25s/it]19:14:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.90s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:15:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.35s/it]19:15:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.99s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:15:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.10s/it]19:15:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.86s/it]
# 19:15:35 - INFO - Progress: 15/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:15:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.23s/it]19:15:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.93s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:15:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.32s/it]19:15:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:15:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.06s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:16:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.32s/it]19:16:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.92s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:16:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.23s/it]19:16:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.81s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:16:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.82s/it]19:16:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.72s/it]
# 19:16:46 - INFO - Progress: 20/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:16:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.22s/it]19:16:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:16:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.99s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:17:01 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.25s/it]19:17:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.07s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:17:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.78s/it]19:17:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.67s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:17:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.00s/it]19:17:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.63s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:17:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.17s/it]19:17:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.05s/it]
# 19:17:56 - INFO - Progress: 25/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:17:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:17:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.58s/it]19:18:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.07s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:18:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.33s/it]19:18:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:20 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.94s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:18:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.15s/it]19:18:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.97s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:18:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.30s/it]19:18:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.02s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:18:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:57 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:18:59 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.07s/it]19:19:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.97s/it]
# 19:19:08 - INFO - Progress: 30/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:19:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.95s/it]19:19:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.86s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.70it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:19:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.32s/it]19:19:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.13s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:19:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.58s/it]19:19:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.56s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:19:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:19:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:05<00:05,  5.40s/it]19:19:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:13<00:00,  6.70s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:20:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.92s/it]19:20:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.82s/it]
# 19:20:19 - INFO - Progress: 35/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.53it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:20:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.95s/it]19:20:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.93s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:20:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.22s/it]19:20:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.97s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:20:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.79s/it]19:20:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:20:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.64s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:21:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.93s/it]19:21:08 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.77s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:21:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.72s/it]19:21:23 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.27s/it]
# 19:21:30 - INFO - Progress: 40/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:21:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:36 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.50s/it]19:21:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.01s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:21:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.86s/it]19:21:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:53 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:21:55 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.58s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:22:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:03 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.23s/it]19:22:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.99s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:22:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.47s/it]19:22:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:22 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.87s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:22:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.28s/it]19:22:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.72s/it]
# 19:22:40 - INFO - Progress: 45/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:22:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:46 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.20s/it]19:22:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:49 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:51 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.01s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:22:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:22:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.40s/it]19:23:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:04 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:06 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.91s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:23:10 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  5.00s/it]19:23:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:18 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.28s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:23:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:29 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.09s/it]19:23:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:35 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.25s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:23:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:44 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.25s/it]19:23:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:50 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.13s/it]
# 19:23:53 - INFO - Progress: 50/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:23:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:23:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.25s/it]19:24:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:05 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.27s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:24:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.23s/it]19:24:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.03s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:24:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:26 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.68s/it]19:24:30 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:32 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:34 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.07s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:24:38 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:40 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:42 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.93s/it]19:24:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:48 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.72s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.86it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:24:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:24:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.45s/it]19:24:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.16s/it]
# 19:25:05 - INFO - Progress: 55/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:25:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:13 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:06<00:06,  6.80s/it]19:25:15 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:17 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:19 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:14<00:00,  7.24s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:25:24 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:25 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:27 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  3.87s/it]19:25:28 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:31 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:33 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.68s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:25:37 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:39 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:41 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.41s/it]19:25:43 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:45 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:47 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.30s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:25:52 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:54 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:25:56 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:04<00:04,  4.55s/it]19:25:58 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:00 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:02 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:12<00:00,  6.20s/it]
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:26:07 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:09 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:11 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating:  50%|█████     | 1/2 [00:03<00:03,  4.00s/it]19:26:12 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:14 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# 19:26:16 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# Evaluating: 100%|██████████| 2/2 [00:11<00:00,  5.68s/it]
# 19:26:19 - INFO - Progress: 60/468 queries
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# Evaluating:   0%|          | 0/2 [00:00<?, ?it/s]19:26:21 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# ...
#     314     model,
#     315     self.queries,
#     316     encode_fn_name="query",
#     317     prompt_name=self.query_prompt_name,
#     318     prompt=self.query_prompt,
#     319 )
#     321 queries_result_list = {}
#     322 for name in self.score_functions:
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\sentence_transformers\evaluation\InformationRetrievalEvaluator.py:427, in InformationRetrievalEvaluator.embed_inputs(self, model, sentences, encode_fn_name, prompt_name, prompt, **kwargs)
#     425 elif encode_fn_name == "document":
#     426     encode_fn = model.encode_document
# --> 427 return encode_fn(
#     428     sentences,
#     429     prompt_name=prompt_name,
#     430     prompt=prompt,
#     431     batch_size=self.batch_size,
#     432     show_progress_bar=self.show_progress_bar,
#     433     convert_to_tensor=True,
#     434     truncate_dim=self.truncate_dim,
#     435     **kwargs,
#     436 )
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:556, in SentenceTransformer.encode_query(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     553 if prompt_name is None and "query" in self.prompts and prompt is None:
#     554     prompt_name = "query"
# --> 556 return self.encode(
#     557     sentences=sentences,
#     558     prompt_name=prompt_name,
#     559     prompt=prompt,
#     560     batch_size=batch_size,
#     561     show_progress_bar=show_progress_bar,
#     562     output_value=output_value,
#     563     precision=precision,
#     564     convert_to_numpy=convert_to_numpy,
#     565     convert_to_tensor=convert_to_tensor,
#     566     device=device,
#     567     normalize_embeddings=normalize_embeddings,
#     568     truncate_dim=truncate_dim,
#     569     pool=pool,
#     570     chunk_size=chunk_size,
#     571     task="query",
#     572     **kwargs,
#     573 )
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\sentence_transformers\models\Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)    258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\utils\generic.py:1002, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#    1000             outputs = func(self, *args, **kwargs)
#    1001     else:
# -> 1002         outputs = func(self, *args, **kwargs)
#    1003 except TypeError as original_exception:
#    1004     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1005     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1006     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1007     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:664, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     647 embedding_output = self.embeddings(
#     648     input_ids=input_ids,
#     649     position_ids=position_ids,
#    (...)    652     past_key_values_length=past_key_values_length,
#     653 )
#     655 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     656     attention_mask=attention_mask,
#     657     encoder_attention_mask=encoder_attention_mask,
#    (...)    661     past_key_values=past_key_values,
#     662 )
# --> 664 encoder_outputs = self.encoder(
#     665     embedding_output,
#     666     attention_mask=attention_mask,
#     667     encoder_hidden_states=encoder_hidden_states,
#     668     encoder_attention_mask=encoder_attention_mask,
#     669     past_key_values=past_key_values,
#     670     use_cache=use_cache,
#     671     cache_position=cache_position,
#     672     position_ids=position_ids,
#     673     **kwargs,
#     674 )
#     675 sequence_output = encoder_outputs.last_hidden_state
#     676 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:547, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     535 def forward(
#     536     self,
#     537     hidden_states: torch.Tensor,
#    (...)    544     **kwargs: Unpack[TransformersKwargs],
#     545 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     546     for i, layer_module in enumerate(self.layer):
# --> 547         hidden_states = layer_module(
#     548             hidden_states,
#     549             attention_mask,
#     550             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     551             encoder_attention_mask=encoder_attention_mask,
#     552             past_key_values=past_key_values,
#     553             cache_position=cache_position,
#     554             **kwargs,
#     555         )
#     557     return BaseModelOutputWithPastAndCrossAttentions(
#     558         last_hidden_state=hidden_states,
#     559         past_key_values=past_key_values if use_cache else None,
#     560     )
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:470, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     460     cross_attention_output, _ = self.crossattention(
#     461         self_attention_output,
#     462         None,  # attention_mask
#    (...)    466         **kwargs,
#     467     )
#     468     attention_output = cross_attention_output
# --> 470 layer_output = apply_chunking_to_forward(
#     471     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     472 )
#     473 return layer_output
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\pytorch_utils.py:201, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     198     # concatenate output at same dimension
#     199     return torch.cat(output_chunks, dim=chunk_dim)
# --> 201 return forward_fn(*input_tensors)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:477, in XLMRobertaLayer.feed_forward_chunk(self, attention_output)
#     475 def feed_forward_chunk(self, attention_output):
#     476     intermediate_output = self.intermediate(attention_output)
# --> 477     layer_output = self.output(intermediate_output, attention_output)
#     478     return layer_output
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:408, in XLMRobertaOutput.forward(self, hidden_states, input_tensor)
#     407 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 408     hidden_states = self.dense(hidden_states)
#     409     hidden_states = self.dropout(hidden_states)
#     410     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Djibs\OneDrive\Dokumen\PFE_Dataset\.venv\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Récupération d'un fichier csv pour les résultats**

# %%
if all_results:
    df_final = pd.DataFrame(all_results)
    
    desired_order = ['Modèle', 'MRR@10', 'NDCG@10', 'Context Precision', 'Context Recall']
    cols = [c for c in desired_order if c in df_final.columns]
    cols += [c for c in df_final.columns if c not in desired_order]
    
    print("\nCLASSEMENT FINAL")
    display(df_final[cols])
    
    # Sauvegarde finale
    df_final.to_csv("resultats_finaux.csv", index=False)
    print("Sauvegardé dans 'resultats_finaux.csv'")
else:
    print("Aucun résultat n'a été généré.")
